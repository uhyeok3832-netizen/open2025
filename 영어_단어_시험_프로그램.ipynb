# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyeok3832-netizen/open2025/blob/main/%EC%98%81%EC%96%B4_%EB%8B%A8%EC%96%B4_%EC%8B%9C%ED%97%98_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def vocab_test():
    words = {
        "apple": "사과",
        "house": "집",
        "school": "학교",
        "computer": "컴퓨터",
        "water": "물"
    }

    score = 0

    for eng, kor in words.items():
        answer = input(f"{eng} 의 뜻은? ")
        if answer.strip() == kor:
            print("✔ 정답!")
            score += 1
        else:
            print(f"✖ 오답! 정답: {kor}")

    print(f"\n📚 총 점수: {score} / {len(words)}")

if __name__ == "__main__":
    vocab_test()
