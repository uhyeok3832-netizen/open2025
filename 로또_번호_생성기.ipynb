# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyeok3832-netizen/open2025/blob/main/%EB%A1%9C%EB%98%90_%EB%B2%88%ED%98%B8_%EC%83%9D%EC%84%B1%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def lotto():
    numbers = sorted(random.sample(range(1, 46), 6))
    return numbers

if __name__ == "__main__":
    print("🎰 로또 번호:", lotto())
# Out:
# 🎰 로또 번호: [8, 22, 30, 32, 39, 42]
